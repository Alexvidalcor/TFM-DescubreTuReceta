# %%
from pyspark.sql import DataFrame, SparkSession, functions as f

# %%
spark = SparkSession.builder.getOrCreate()

# %%
from os import sep


file = "dataset_recetas_espanol.csv"
df = spark.read.option("header", "true").options(delimiter='|').csv(file)

# %%
df.show(10, 0)
# Out:
# +---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
df.select(f.col("Ingredientes")).show(10, 0)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ...
